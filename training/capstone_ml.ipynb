# %%
import pandas as pd
import numpy as np
import openpyxl
import seaborn as sb
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

#for preprocessing
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder, OneHotEncoder, OrdinalEncoder
import joblib

#for earlystopping
from tensorflow.keras.callbacks import EarlyStopping

#for resampling 
from imblearn.over_sampling import RandomOverSampler

#for model
from tensorflow import keras
import tensorflow as tf

#for checking testing results
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, classification_report, confusion_matrix

# %% [markdown]
# # Import Data

# %%
data=pd.read_csv("Sleep_health_and_lifestyle_dataset.csv")
data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 1                   6                       60             8       Normal
# 2                   6                       60             8       Normal
# 3                   4                       30             8        Obese
# 4                   4                       30             8        Obese
# ..                ...                      ...           ...          ...
# 369                 9                       75             3   Overweight
# 370                 9                       75             3   Overweight
# 371                 9                       75             3   Overweight
# 372                 9                       75             3   Overweight
# 373                 9                       75             3   Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0           126/83          77         4200            NaN
# 1           125/80          75        10000            NaN
# 2           125/80          75        10000            NaN
# 3           140/90          85         3000    Sleep Apnea
# 4           140/90          85         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [374 rows x 13 columns]

# %% [markdown]
# # EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
data.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# 25%                  45.000000      4.000000   68.000000   5600.000000
# 50%                  60.000000      5.000000   70.000000   7000.000000
# 75%                  75.000000      7.000000   72.000000   8000.000000
# max                  90.000000      8.000000   86.000000  10000.000000

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      189
# Female    185
# Name: count, dtype: int64

# %%
data['Occupation'].value_counts()
# Out:
# Occupation
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: count, dtype: int64

# %%
data['Quality of Sleep'].value_counts()
# Out:
# Quality of Sleep
# 8    109
# 6    105
# 7     77
# 9     71
# 5      7
# 4      5
# Name: count, dtype: int64

# %%
data['Stress Level'].value_counts()
# Out:
# Stress Level
# 3    71
# 8    70
# 4    70
# 5    67
# 7    50
# 6    46
# Name: count, dtype: int64

# %%
data['BMI Category'].value_counts()
# Out:
# BMI Category
# Normal           195
# Overweight       148
# Normal Weight     21
# Obese             10
# Name: count, dtype: int64

# %%
data['Blood Pressure'].value_counts()
# Out:
# Blood Pressure
# 130/85    99
# 140/95    65
# 125/80    65
# 120/80    45
# 115/75    32
# 135/90    27
# 140/90     4
# 125/82     4
# 132/87     3
# 128/85     3
# 126/83     2
# 115/78     2
# 139/91     2
# 142/92     2
# 119/77     2
# 135/88     2
# 129/84     2
# 128/84     2
# 131/86     2
# 117/76     2
# 130/86     2
# 118/75     2
# 121/79     1
# 122/80     1
# 118/76     1
# Name: count, dtype: int64

# %%
data['Sleep Disorder'].value_counts()
# Out:
# Sleep Disorder
# Sleep Apnea    78
# Insomnia       77
# Name: count, dtype: int64

# %% [markdown]
# # Preprocessing Data

# %%
data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 1                   6                       60             8       Normal
# 2                   6                       60             8       Normal
# 3                   4                       30             8        Obese
# 4                   4                       30             8        Obese
# ..                ...                      ...           ...          ...
# 369                 9                       75             3   Overweight
# 370                 9                       75             3   Overweight
# 371                 9                       75             3   Overweight
# 372                 9                       75             3   Overweight
# 373                 9                       75             3   Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0           126/83          77         4200            NaN
# 1           125/80          75        10000            NaN
# 2           125/80          75        10000            NaN
# 3           140/90          85         3000    Sleep Apnea
# 4           140/90          85         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [374 rows x 13 columns]

# %%
#menghitung missing value
data.isnull().sum()
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
# rename the following columns
data.rename(columns={'Sleep Duration':'Sleep_Duration',
                    'Quality of Sleep':'Sleep_Quality',
                    'Physical Activity Level':'Physical_Activity_Level',
                    'Stress Level':'Stress_Level',
                    'BMI Category':'BMI_Category',
                    'Blood Pressure':'Blood_Pressure',
                    'Heart Rate':'Heart_Rate',
                    'Daily Steps':'Daily_Steps',
                    'Sleep Disorder':'Sleep_Disorder'}, inplace=True)
data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep_Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Sleep_Quality  Physical_Activity_Level  Stress_Level BMI_Category  \
# 0                6                       42             6   Overweight
# 1                6                       60             8       Normal
# 2                6                       60             8       Normal
# 3                4                       30             8        Obese
# 4                4                       30             8        Obese
# ..             ...                      ...           ...          ...
# 369              9                       75             3   Overweight
# 370              9                       75             3   Overweight
# 371              9                       75             3   Overweight
# 372              9                       75             3   Overweight
# 373              9                       75             3   Overweight
#
#     Blood_Pressure  Heart_Rate  Daily_Steps Sleep_Disorder
# 0           126/83          77         4200            NaN
# 1           125/80          75        10000            NaN
# 2           125/80          75        10000            NaN
# 3           140/90          85         3000    Sleep Apnea
# 4           140/90          85         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [374 rows x 13 columns]

# %%
# the category `Normal` & `Normal Weight` in column `BMI_Category` have similar meaning
# convert the `Normal Weight` to `Normal`
data['BMI_Category'] = np.where(data['BMI_Category']=='Normal Weight', 'Normal', data['BMI_Category'])
data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep_Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Sleep_Quality  Physical_Activity_Level  Stress_Level BMI_Category  \
# 0                6                       42             6   Overweight
# 1                6                       60             8       Normal
# 2                6                       60             8       Normal
# 3                4                       30             8        Obese
# 4                4                       30             8        Obese
# ..             ...                      ...           ...          ...
# 369              9                       75             3   Overweight
# 370              9                       75             3   Overweight
# 371              9                       75             3   Overweight
# 372              9                       75             3   Overweight
# 373              9                       75             3   Overweight
#
#     Blood_Pressure  Heart_Rate  Daily_Steps Sleep_Disorder
# 0           126/83          77         4200            NaN
# 1           125/80          75        10000            NaN
# 2           125/80          75        10000            NaN
# 3           140/90          85         3000    Sleep Apnea
# 4           140/90          85         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [374 rows x 13 columns]

# %%
# extract the systolic & diastolic blood pressure values from column `Blood_Pressure`
data['Systolic'] = data['Blood_Pressure'].str.split('/').str[0].astype(int)
data['Diastolic'] = data['Blood_Pressure'].str.split('/').str[1].astype(int)

# %%
# define a function to categorize the hypertesion stage based on the guidelines from
# American College of Cardiology and the American Heart Association

def bp_category(systolic, diastolic):
    if systolic <= 120 and diastolic <= 80:
        return 'Normal'
    elif 120 < systolic <= 129 and diastolic <= 80:
        return 'Elevated'
    elif (130 <= systolic <= 139) or (80 < diastolic < 89):
        return 'Stage 1'
    else:
        return 'Stage 2'

# %%
# create a new column in the dataset `BP_Category`
data['BP_Category'] = data.apply(lambda row: bp_category(row['Systolic'], row['Diastolic']), axis=1)

# %%
# column `Sleeop_Disorder` contains information of 
# the presence or absence of a sleep disorder in the person (None, Insomnia, Sleep Apnea)
# the `NaN` value indicates no sleep disorder
# convert the `NaN` value to `Normal`

data['Sleep_Disorder'] = np.where(data['Sleep_Disorder'].isna(), 'Normal', data['Sleep_Disorder'])
data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep_Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Sleep_Quality  Physical_Activity_Level  Stress_Level BMI_Category  \
# 0                6                       42             6   Overweight
# 1                6                       60             8       Normal
# 2                6                       60             8       Normal
# 3                4                       30             8        Obese
# 4                4                       30             8        Obese
# ..             ...                      ...           ...          ...
# 369              9                       75             3   Overweight
# 370              9                       75             3   Overweight
# 371              9                       75             3   Overweight
# 372              9                       75             3   Overweight
# 373              9                       75             3   Overweight
#
#     Blood_Pressure  Heart_Rate  Daily_Steps Sleep_Disorder  Systolic  \
# 0           126/83          77         4200         Normal       126
# 1           125/80          75        10000         Normal       125
# 2           125/80          75        10000         Normal       125
# 3           140/90          85         3000    Sleep Apnea       140
# 4           140/90          85         3000    Sleep Apnea       140
# ..             ...         ...          ...            ...       ...
# 369         140/95          68         7000    Sleep Apnea       140
# 370         140/95          68         7000    Sleep Apnea       140
# 371         140/95          68         7000    Sleep Apnea       140
# 372         140/95          68         7000    Sleep Apnea       140
# 373         140/95          68         7000    Sleep Apnea       140
#
#      Diastolic BP_Category
# 0           83     Stage 1
# 1           80    Elevated
# 2           80    Elevated
# 3           90     Stage 2
# 4           90     Stage 2
# ..         ...         ...
# 369         95     Stage 2
# 370         95     Stage 2
# 371         95     Stage 2
# 372         95     Stage 2
# 373         95     Stage 2
#
# [374 rows x 16 columns]

# %%
data['BP_Category'].value_counts()
# Out:
# BP_Category
# Stage 1     150
# Normal       86
# Stage 2      71
# Elevated     67
# Name: count, dtype: int64

# %%
# drop columns `Blood_Pressure`, 'Systolic', 'Diastolic'
data.drop(columns=['Blood_Pressure', 'Systolic', 'Diastolic','Person ID','Occupation'], axis=1, inplace=True)
data
# Out:
#      Gender  Age  Sleep_Duration  Sleep_Quality  Physical_Activity_Level  \
# 0      Male   27             6.1              6                       42
# 1      Male   28             6.2              6                       60
# 2      Male   28             6.2              6                       60
# 3      Male   28             5.9              4                       30
# 4      Male   28             5.9              4                       30
# ..      ...  ...             ...            ...                      ...
# 369  Female   59             8.1              9                       75
# 370  Female   59             8.0              9                       75
# 371  Female   59             8.1              9                       75
# 372  Female   59             8.1              9                       75
# 373  Female   59             8.1              9                       75
#
#      Stress_Level BMI_Category  Heart_Rate  Daily_Steps Sleep_Disorder  \
# 0               6   Overweight          77         4200         Normal
# 1               8       Normal          75        10000         Normal
# 2               8       Normal          75        10000         Normal
# 3               8        Obese          85         3000    Sleep Apnea
# 4               8        Obese          85         3000    Sleep Apnea
# ..            ...          ...         ...          ...            ...
# 369             3   Overweight          68         7000    Sleep Apnea
# 370             3   Overweight          68         7000    Sleep Apnea
# 371             3   Overweight          68         7000    Sleep Apnea
# 372             3   Overweight          68         7000    Sleep Apnea
# 373             3   Overweight          68         7000    Sleep Apnea
#
#     BP_Category
# 0       Stage 1
# 1      Elevated
# 2      Elevated
# 3       Stage 2
# 4       Stage 2
# ..          ...
# 369     Stage 2
# 370     Stage 2
# 371     Stage 2
# 372     Stage 2
# 373     Stage 2
#
# [374 rows x 11 columns]

# %%
data["BP_Category"].value_counts()
# Out:
# BP_Category
# Stage 1     150
# Normal       86
# Stage 2      71
# Elevated     67
# Name: count, dtype: int64

# %%
# Inisialisasi LabelEncoder
label_encoder = LabelEncoder()

# Daftar variabel yang akan di-label encoding
categorical_columns = ['Gender', 'Sleep_Quality', 'Stress_Level', 'BMI_Category', 'BP_Category', 'Sleep_Disorder']

# Melakukan label encoding untuk setiap variabel kategori
for column in categorical_columns:
    data[column] = label_encoder.fit_transform(data[column])

data
# Out:
#      Gender  Age  Sleep_Duration  Sleep_Quality  Physical_Activity_Level  \
# 0         1   27             6.1              2                       42
# 1         1   28             6.2              2                       60
# 2         1   28             6.2              2                       60
# 3         1   28             5.9              0                       30
# 4         1   28             5.9              0                       30
# ..      ...  ...             ...            ...                      ...
# 369       0   59             8.1              5                       75
# 370       0   59             8.0              5                       75
# 371       0   59             8.1              5                       75
# 372       0   59             8.1              5                       75
# 373       0   59             8.1              5                       75
#
#      Stress_Level  BMI_Category  Heart_Rate  Daily_Steps  Sleep_Disorder  \
# 0               3             2          77         4200               1
# 1               5             0          75        10000               1
# 2               5             0          75        10000               1
# 3               5             1          85         3000               2
# 4               5             1          85         3000               2
# ..            ...           ...         ...          ...             ...
# 369             0             2          68         7000               2
# 370             0             2          68         7000               2
# 371             0             2          68         7000               2
# 372             0             2          68         7000               2
# 373             0             2          68         7000               2
#
#      BP_Category
# 0              2
# 1              0
# 2              0
# 3              3
# 4              3
# ..           ...
# 369            3
# 370            3
# 371            3
# 372            3
# 373            3
#
# [374 rows x 11 columns]

# %%
data_sleep_disorder_0 = data[data['Sleep_Disorder'] == 0]

# Menampilkan data yang telah difilter
data_sleep_disorder_0
# Out:
#      Gender  Age  Sleep_Duration  Sleep_Quality  Physical_Activity_Level  \
# 5         1   28             5.9              0                       30
# 6         1   29             6.3              2                       40
# 18        0   29             6.5              1                       40
# 31        0   30             6.4              1                       35
# 67        1   33             6.0              2                       30
# ..      ...  ...             ...            ...                      ...
# 308       0   52             6.6              3                       45
# 309       0   52             6.6              3                       45
# 310       0   52             6.6              3                       45
# 311       0   52             6.6              3                       45
# 315       0   53             8.3              5                       30
#
#      Stress_Level  BMI_Category  Heart_Rate  Daily_Steps  Sleep_Disorder  \
# 5               5             1          85         3000               0
# 6               4             1          82         3500               0
# 18              4             0          80         4000               0
# 31              4             0          78         4100               0
# 67              5             0          72         5000               0
# ..            ...           ...         ...          ...             ...
# 308             4             2          72         6000               0
# 309             4             2          72         6000               0
# 310             4             2          72         6000               0
# 311             4             2          72         6000               0
# 315             0             0          65         5000               0
#
#      BP_Category
# 5              3
# 6              3
# 18             2
# 31             2
# 67             0
# ..           ...
# 308            2
# 309            2
# 310            2
# 311            2
# 315            0
#
# [77 rows x 11 columns]

# %%
data_sleep_disorder_1 = data[data['Sleep_Disorder'] == 1]

# Menampilkan data yang telah difilter
data_sleep_disorder_1
# Out:
#      Gender  Age  Sleep_Duration  Sleep_Quality  Physical_Activity_Level  \
# 0         1   27             6.1              2                       42
# 1         1   28             6.2              2                       60
# 2         1   28             6.2              2                       60
# 7         1   29             7.8              3                       75
# 8         1   29             7.8              3                       75
# ..      ...  ...             ...            ...                      ...
# 341       0   56             8.2              5                       90
# 342       0   56             8.2              5                       90
# 343       0   57             8.1              5                       75
# 358       0   59             8.0              5                       75
# 359       0   59             8.1              5                       75
#
#      Stress_Level  BMI_Category  Heart_Rate  Daily_Steps  Sleep_Disorder  \
# 0               3             2          77         4200               1
# 1               5             0          75        10000               1
# 2               5             0          75        10000               1
# 7               3             0          70         8000               1
# 8               3             0          70         8000               1
# ..            ...           ...         ...          ...             ...
# 341             0             0          65        10000               1
# 342             0             0          65        10000               1
# 343             0             2          68         7000               1
# 358             0             2          68         7000               1
# 359             0             2          68         7000               1
#
#      BP_Category
# 0              2
# 1              0
# 2              0
# 7              1
# 8              1
# ..           ...
# 341            1
# 342            1
# 343            3
# 358            3
# 359            3
#
# [219 rows x 11 columns]

# %%
data_sleep_disorder_2 = data[data['Sleep_Disorder'] == 2]

# Menampilkan data yang telah difilter
data_sleep_disorder_2
# Out:
#      Gender  Age  Sleep_Duration  Sleep_Quality  Physical_Activity_Level  \
# 3         1   28             5.9              0                       30
# 4         1   28             5.9              0                       30
# 16        0   29             6.5              1                       40
# 17        1   29             6.0              2                       30
# 30        0   30             6.4              1                       35
# ..      ...  ...             ...            ...                      ...
# 369       0   59             8.1              5                       75
# 370       0   59             8.0              5                       75
# 371       0   59             8.1              5                       75
# 372       0   59             8.1              5                       75
# 373       0   59             8.1              5                       75
#
#      Stress_Level  BMI_Category  Heart_Rate  Daily_Steps  Sleep_Disorder  \
# 3               5             1          85         3000               2
# 4               5             1          85         3000               2
# 16              4             0          80         4000               2
# 17              5             0          70         8000               2
# 30              4             0          78         4100               2
# ..            ...           ...         ...          ...             ...
# 369             0             2          68         7000               2
# 370             0             2          68         7000               2
# 371             0             2          68         7000               2
# 372             0             2          68         7000               2
# 373             0             2          68         7000               2
#
#      BP_Category
# 3              3
# 4              3
# 16             2
# 17             1
# 30             2
# ..           ...
# 369            3
# 370            3
# 371            3
# 372            3
# 373            3
#
# [78 rows x 11 columns]

# %%
# Mengambil variabel yang akan dinormalisasi
columns_to_normalize = ['Age', 'Sleep_Duration', 'Physical_Activity_Level', 'Heart_Rate', 'Daily_Steps']

# Melakukan normalisasi
scaler = MinMaxScaler()
data[columns_to_normalize] = scaler.fit_transform(data[columns_to_normalize])
data
# Out:
#      Gender      Age  Sleep_Duration  Sleep_Quality  Physical_Activity_Level  \
# 0         1  0.00000        0.111111              2                     0.20
# 1         1  0.03125        0.148148              2                     0.50
# 2         1  0.03125        0.148148              2                     0.50
# 3         1  0.03125        0.037037              0                     0.00
# 4         1  0.03125        0.037037              0                     0.00
# ..      ...      ...             ...            ...                      ...
# 369       0  1.00000        0.851852              5                     0.75
# 370       0  1.00000        0.814815              5                     0.75
# 371       0  1.00000        0.851852              5                     0.75
# 372       0  1.00000        0.851852              5                     0.75
# 373       0  1.00000        0.851852              5                     0.75
#
#      Stress_Level  BMI_Category  Heart_Rate  Daily_Steps  Sleep_Disorder  \
# 0               3             2    0.571429     0.171429               1
# 1               5             0    0.476190     1.000000               1
# 2               5             0    0.476190     1.000000               1
# 3               5             1    0.952381     0.000000               2
# 4               5             1    0.952381     0.000000               2
# ..            ...           ...         ...          ...             ...
# 369             0             2    0.142857     0.571429               2
# 370             0             2    0.142857     0.571429               2
# 371             0             2    0.142857     0.571429               2
# 372             0             2    0.142857     0.571429               2
# 373             0             2    0.142857     0.571429               2
#
#      BP_Category
# 0              2
# 1              0
# 2              0
# 3              3
# 4              3
# ..           ...
# 369            3
# 370            3
# 371            3
# 372            3
# 373            3
#
# [374 rows x 11 columns]

# %%
# Menyimpan model normalisasi menggunakan joblib
joblib.dump(scaler, 'normalization_model.joblib')
# Out:
# ['normalization_model.joblib']

# %%
data_sleep_disorder0 = data[data['Sleep_Disorder'] == 0]

# Menampilkan data yang telah difilter
data_sleep_disorder0
# Out:
#      Gender      Age  Sleep_Duration  Sleep_Quality  Physical_Activity_Level  \
# 5         1  0.03125        0.037037              0                 0.000000
# 6         1  0.06250        0.185185              2                 0.166667
# 18        0  0.06250        0.259259              1                 0.166667
# 31        0  0.09375        0.222222              1                 0.083333
# 67        1  0.18750        0.074074              2                 0.000000
# ..      ...      ...             ...            ...                      ...
# 308       0  0.78125        0.296296              3                 0.250000
# 309       0  0.78125        0.296296              3                 0.250000
# 310       0  0.78125        0.296296              3                 0.250000
# 311       0  0.78125        0.296296              3                 0.250000
# 315       0  0.81250        0.925926              5                 0.000000
#
#      Stress_Level  BMI_Category  Heart_Rate  Daily_Steps  Sleep_Disorder  \
# 5               5             1    0.952381     0.000000               0
# 6               4             1    0.809524     0.071429               0
# 18              4             0    0.714286     0.142857               0
# 31              4             0    0.619048     0.157143               0
# 67              5             0    0.333333     0.285714               0
# ..            ...           ...         ...          ...             ...
# 308             4             2    0.333333     0.428571               0
# 309             4             2    0.333333     0.428571               0
# 310             4             2    0.333333     0.428571               0
# 311             4             2    0.333333     0.428571               0
# 315             0             0    0.000000     0.285714               0
#
#      BP_Category
# 5              3
# 6              3
# 18             2
# 31             2
# 67             0
# ..           ...
# 308            2
# 309            2
# 310            2
# 311            2
# 315            0
#
# [77 rows x 11 columns]

# %%
data_sleep_disorder1 = data[data['Sleep_Disorder'] == 1]

# Menampilkan data yang telah difilter
data_sleep_disorder1
# Out:
#      Gender      Age  Sleep_Duration  Sleep_Quality  Physical_Activity_Level  \
# 0         1  0.00000        0.111111              2                     0.20
# 1         1  0.03125        0.148148              2                     0.50
# 2         1  0.03125        0.148148              2                     0.50
# 7         1  0.06250        0.740741              3                     0.75
# 8         1  0.06250        0.740741              3                     0.75
# ..      ...      ...             ...            ...                      ...
# 341       0  0.90625        0.888889              5                     1.00
# 342       0  0.90625        0.888889              5                     1.00
# 343       0  0.93750        0.851852              5                     0.75
# 358       0  1.00000        0.814815              5                     0.75
# 359       0  1.00000        0.851852              5                     0.75
#
#      Stress_Level  BMI_Category  Heart_Rate  Daily_Steps  Sleep_Disorder  \
# 0               3             2    0.571429     0.171429               1
# 1               5             0    0.476190     1.000000               1
# 2               5             0    0.476190     1.000000               1
# 7               3             0    0.238095     0.714286               1
# 8               3             0    0.238095     0.714286               1
# ..            ...           ...         ...          ...             ...
# 341             0             0    0.000000     1.000000               1
# 342             0             0    0.000000     1.000000               1
# 343             0             2    0.142857     0.571429               1
# 358             0             2    0.142857     0.571429               1
# 359             0             2    0.142857     0.571429               1
#
#      BP_Category
# 0              2
# 1              0
# 2              0
# 7              1
# 8              1
# ..           ...
# 341            1
# 342            1
# 343            3
# 358            3
# 359            3
#
# [219 rows x 11 columns]

# %%
data_sleep_disorder2 = data[data['Sleep_Disorder'] == 2]

# Menampilkan data yang telah difilter
data_sleep_disorder2
# Out:
#      Gender      Age  Sleep_Duration  Sleep_Quality  Physical_Activity_Level  \
# 3         1  0.03125        0.037037              0                 0.000000
# 4         1  0.03125        0.037037              0                 0.000000
# 16        0  0.06250        0.259259              1                 0.166667
# 17        1  0.06250        0.074074              2                 0.000000
# 30        0  0.09375        0.222222              1                 0.083333
# ..      ...      ...             ...            ...                      ...
# 369       0  1.00000        0.851852              5                 0.750000
# 370       0  1.00000        0.814815              5                 0.750000
# 371       0  1.00000        0.851852              5                 0.750000
# 372       0  1.00000        0.851852              5                 0.750000
# 373       0  1.00000        0.851852              5                 0.750000
#
#      Stress_Level  BMI_Category  Heart_Rate  Daily_Steps  Sleep_Disorder  \
# 3               5             1    0.952381     0.000000               2
# 4               5             1    0.952381     0.000000               2
# 16              4             0    0.714286     0.142857               2
# 17              5             0    0.238095     0.714286               2
# 30              4             0    0.619048     0.157143               2
# ..            ...           ...         ...          ...             ...
# 369             0             2    0.142857     0.571429               2
# 370             0             2    0.142857     0.571429               2
# 371             0             2    0.142857     0.571429               2
# 372             0             2    0.142857     0.571429               2
# 373             0             2    0.142857     0.571429               2
#
#      BP_Category
# 3              3
# 4              3
# 16             2
# 17             1
# 30             2
# ..           ...
# 369            3
# 370            3
# 371            3
# 372            3
# 373            3
#
# [78 rows x 11 columns]

# %% [markdown]
# # VISUALIZATION

# %%
# Visualization of Sleep Duration distribution based on Sleep Disorder
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='Sleep_Duration', hue='Sleep_Disorder', bins=30, kde=True)
plt.title('Distribution of Sleep Duration by Nyenyak')
plt.xlabel('Sleep Duration')
plt.ylabel('Count')
plt.legend(title='Sleep Disorder')
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Visualization of correlation between variables
correlation_matrix = data.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
# Comparative visualization of the Sleep Disorder category against other variables
sns.pairplot(data=data, hue='Sleep_Disorder', palette='husl')
plt.suptitle('Pairplot of Variables by Sleep Disorder', y=1.02)
plt.show()

# %%
# Visualization of Sleep Duration comparison based on BMI Category
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='BMI_Category', y='Sleep_Duration', hue='BMI_Category')
plt.title('Boxplot of Sleep Duration by BMI Category')
plt.xlabel('BMI Category')
plt.ylabel('Sleep Duration')
plt.legend(title='BMI Category')
plt.show()

# %%
# Visualization of Sleep Disorder categories based on gender (Gender)
plt.figure(figsize=(8, 5))
sns.countplot(data=data, x='Sleep_Disorder', hue='Gender')
plt.title('Count of Sleep Disorder by Gender')
plt.xlabel('Sleep Disorder')
plt.ylabel('Count')
plt.legend(title='Gender')
plt.show()

# %%
# Visualization of the comparison of Heart Rate to Stress Level
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Heart_Rate', y='Stress_Level', hue='Stress_Level', palette='viridis')
plt.title('Scatterplot of Heart Rate vs Stress Level')
plt.xlabel('Heart Rate')
plt.ylabel('Stress Level')
plt.legend(title='Stress Level')
plt.show()

# %% [markdown]
# # Make ANN Model

# %%
#feature selection data and split data
X = data.drop(columns='Sleep_Disorder')
y = data.Sleep_Disorder

# %%
X
# Out:
#      Gender      Age  Sleep_Duration  Sleep_Quality  Physical_Activity_Level  \
# 0         1  0.00000        0.111111              2                     0.20
# 1         1  0.03125        0.148148              2                     0.50
# 2         1  0.03125        0.148148              2                     0.50
# 3         1  0.03125        0.037037              0                     0.00
# 4         1  0.03125        0.037037              0                     0.00
# ..      ...      ...             ...            ...                      ...
# 369       0  1.00000        0.851852              5                     0.75
# 370       0  1.00000        0.814815              5                     0.75
# 371       0  1.00000        0.851852              5                     0.75
# 372       0  1.00000        0.851852              5                     0.75
# 373       0  1.00000        0.851852              5                     0.75
#
#      Stress_Level  BMI_Category  Heart_Rate  Daily_Steps  BP_Category
# 0               3             2    0.571429     0.171429            2
# 1               5             0    0.476190     1.000000            0
# 2               5             0    0.476190     1.000000            0
# 3               5             1    0.952381     0.000000            3
# 4               5             1    0.952381     0.000000            3
# ..            ...           ...         ...          ...          ...
# 369             0             2    0.142857     0.571429            3
# 370             0             2    0.142857     0.571429            3
# 371             0             2    0.142857     0.571429            3
# 372             0             2    0.142857     0.571429            3
# 373             0             2    0.142857     0.571429            3
#
# [374 rows x 10 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      2
# 4      2
#       ..
# 369    2
# 370    2
# 371    2
# 372    2
# 373    2
# Name: Sleep_Disorder, Length: 374, dtype: int32

# %%
y.value_counts()
# Out:
# Sleep_Disorder
# 1    219
# 2     78
# 0     77
# Name: count, dtype: int64

# %%
#resampling
oversample = RandomOverSampler(sampling_strategy='auto')

X_ros, y_ros = oversample.fit_resample(X, y)

# %%
#data traing 90% dan data testing 10% before random oversampling
X_train, X_test, y_train, y_test = train_test_split(X_ros, y_ros, test_size=0.2, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((525, 10), (132, 10), (525,), (132,))

# %%
X_train
# Out:
#      Gender      Age  Sleep_Duration  Sleep_Quality  Physical_Activity_Level  \
# 227       1  0.53125        0.185185              2                     0.25
# 559       0  0.71875        0.074074              2                     1.00
# 363       0  1.00000        0.888889              5                     0.75
# 61        1  0.15625        0.074074              2                     0.00
# 578       0  0.71875        0.074074              2                     1.00
# ..      ...      ...             ...            ...                      ...
# 71        1  0.18750        0.111111              2                     0.00
# 106       0  0.31250        0.111111              2                     0.20
# 270       0  0.68750        0.111111              2                     1.00
# 435       0  0.56250        0.370370              3                     0.00
# 102       0  0.28125        0.518519              4                     0.50
#
#      Stress_Level  BMI_Category  Heart_Rate  Daily_Steps  BP_Category
# 227             4             2    0.333333     0.428571            2
# 559             5             2    0.476190     1.000000            3
# 363             0             2    0.142857     0.571429            3
# 61              5             0    0.333333     0.285714            0
# 578             5             2    0.476190     1.000000            3
# ..            ...           ...         ...          ...          ...
# 71              5             0    0.333333     0.285714            0
# 106             3             2    0.571429     0.171429            2
# 270             5             2    0.476190     1.000000            3
# 435             3             2    0.000000     0.428571            2
# 102             1             0    0.142857     0.571429            1
#
# [525 rows x 10 columns]

# %%
X_test
# Out:
#      Gender      Age  Sleep_Duration  Sleep_Quality  Physical_Activity_Level  \
# 627       0  0.71875        0.074074              2                 1.000000
# 271       0  0.68750        0.111111              2                 1.000000
# 290       0  0.71875        0.074074              2                 1.000000
# 63        1  0.15625        0.148148              2                 0.000000
# 302       0  0.75000        0.481481              3                 0.416667
# ..      ...      ...             ...            ...                      ...
# 70        1  0.18750        0.111111              2                 0.000000
# 403       0  0.53125        0.296296              3                 0.250000
# 336       0  0.84375        0.962963              5                 0.000000
# 541       0  0.75000        0.111111              2                 1.000000
# 18        0  0.06250        0.259259              1                 0.166667
#
#      Stress_Level  BMI_Category  Heart_Rate  Daily_Steps  BP_Category
# 627             5             2    0.476190     1.000000            3
# 271             5             2    0.476190     1.000000            3
# 290             5             2    0.476190     1.000000            3
# 63              5             0    0.333333     0.285714            0
# 302             3             0    0.333333     0.428571            2
# ..            ...           ...         ...          ...          ...
# 70              5             0    0.333333     0.285714            0
# 403             1             2    0.000000     0.428571            2
# 336             0             0    0.000000     0.285714            0
# 541             5             2    0.476190     1.000000            3
# 18              4             0    0.714286     0.142857            2
#
# [132 rows x 10 columns]

# %%
y_train
# Out:
# 227    0
# 559    2
# 363    2
# 61     1
# 578    2
#       ..
# 71     1
# 106    1
# 270    2
# 435    0
# 102    1
# Name: Sleep_Disorder, Length: 525, dtype: int32

# %%
y_test
# Out:
# 627    2
# 271    2
# 290    2
# 63     1
# 302    1
#       ..
# 70     1
# 403    0
# 336    1
# 541    2
# 18     0
# Name: Sleep_Disorder, Length: 132, dtype: int32

# %%
y_ros.value_counts()
# Out:
# Sleep_Disorder
# 1    219
# 2    219
# 0    219
# Name: count, dtype: int64

# %%
#data traing 90% dan data testing 10% before random oversampling
X_train, X_test, y_train, y_test = train_test_split(X_ros, y_ros, test_size=0.2, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((525, 10), (132, 10), (525,), (132,))

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(10,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# %%
scce = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-3)

model.compile(
    loss=scce,
    optimizer=optimizer,
    metrics=['accuracy']
)

# %%
# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=128, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 5/5 [==============================] - 4s 171ms/step - loss: 1.0437 - accuracy: 0.4210 - val_loss: 0.9671 - val_accuracy: 0.7424
# Epoch 2/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.9372 - accuracy: 0.7448 - val_loss: 0.9016 - val_accuracy: 0.6667
# Epoch 3/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.8550 - accuracy: 0.7295 - val_loss: 0.8111 - val_accuracy: 0.6667
# Epoch 4/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.7645 - accuracy: 0.7352 - val_loss: 0.7286 - val_accuracy: 0.8258
# Epoch 5/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.6891 - accuracy: 0.8495 - val_loss: 0.6592 - val_accuracy: 0.8409
# Epoch 6/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.6241 - accuracy: 0.8552 - val_loss: 0.5857 - val_accuracy: 0.8333
# Epoch 7/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5738 - accuracy: 0.8552 - val_loss: 0.5380 - val_accuracy: 0.8333
# Epoch 8/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5269 - accuracy: 0.8590 - val_loss: 0.5330 - val_accuracy: 0.8561
# Epoch 9/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5024 - accuracy: 0.8667 - val_loss: 0.4862 - val_accuracy: 0.8561
# Epoch 10/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.4903 - accuracy: 0.8667 - val_loss: 0.4878 - val_accuracy: 0.8561
# Epoch 11/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4670 - accuracy: 0.8667 - val_loss: 0.4854 - val_accuracy: 0.8561
# Epoch 12/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4638 - accuracy: 0.8686 - val_loss: 0.4522 - val_accuracy: 0.8561
# Epoch 13/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4434 - accuracy: 0.8667 - val_loss: 0.4575 - val_accuracy: 0.8561
# Epoch 14/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4388 - accuracy: 0.8705 - val_loss: 0.4461 - val_accuracy: 0.8561
# Epoch 15/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4295 - accuracy: 0.8667 - val_loss: 0.4389 - val_accuracy: 0.8561
# Epoch 16/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4257 - accuracy: 0.8705 - val_loss: 0.4418 - val_accuracy: 0.8561
# Epoch 17/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4199 - accuracy: 0.8705 - val_loss: 0.4214 - val_accuracy: 0.8561
# Epoch 18/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4223 - accuracy: 0.8705 - val_loss: 0.4284 - val_accuracy: 0.8561
# Epoch 19/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4225 - accuracy: 0.8705 - val_loss: 0.4215 - val_accuracy: 0.8561
# Epoch 20/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.4141 - accuracy: 0.8705 - val_loss: 0.4178 - val_accuracy: 0.8864
# Epoch 21/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4126 - accuracy: 0.8781 - val_loss: 0.4048 - val_accuracy: 0.8864
# Epoch 22/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4104 - accuracy: 0.8762 - val_loss: 0.4036 - val_accuracy: 0.8864
# Epoch 23/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4102 - accuracy: 0.8762 - val_loss: 0.4160 - val_accuracy: 0.8561
# Epoch 24/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4106 - accuracy: 0.8705 - val_loss: 0.4171 - val_accuracy: 0.8561
# Epoch 25/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4081 - accuracy: 0.8743 - val_loss: 0.4004 - val_accuracy: 0.8864
# Epoch 26/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.4028 - accuracy: 0.8762 - val_loss: 0.4074 - val_accuracy: 0.8712
# Epoch 27/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.4008 - accuracy: 0.8762 - val_loss: 0.4060 - val_accuracy: 0.8864
# Epoch 28/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4090 - accuracy: 0.8762 - val_loss: 0.4033 - val_accuracy: 0.8864
# Epoch 29/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4005 - accuracy: 0.8800 - val_loss: 0.4229 - val_accuracy: 0.8561
# Epoch 30/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4006 - accuracy: 0.8743 - val_loss: 0.4082 - val_accuracy: 0.8864
# Epoch 31/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3998 - accuracy: 0.8781 - val_loss: 0.4131 - val_accuracy: 0.8712
# Epoch 32/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3989 - accuracy: 0.8838 - val_loss: 0.3859 - val_accuracy: 0.8939
# Epoch 33/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3944 - accuracy: 0.8895 - val_loss: 0.3890 - val_accuracy: 0.8939
# Epoch 34/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3950 - accuracy: 0.8762 - val_loss: 0.3955 - val_accuracy: 0.8864
# Epoch 35/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.3992 - accuracy: 0.8819 - val_loss: 0.4008 - val_accuracy: 0.8864
# Epoch 36/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3925 - accuracy: 0.8762 - val_loss: 0.4165 - val_accuracy: 0.8712
# Epoch 37/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3949 - accuracy: 0.8762 - val_loss: 0.3870 - val_accuracy: 0.8939
# Epoch 38/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3854 - accuracy: 0.8895 - val_loss: 0.4028 - val_accuracy: 0.8864
# Epoch 39/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4071 - accuracy: 0.8724 - val_loss: 0.4540 - val_accuracy: 0.8485
# Epoch 40/100
# 5/5 [==============================] - 0s 19ms/step - loss: 0.3981 - accuracy: 0.8781 - val_loss: 0.3907 - val_accuracy: 0.8939
# Epoch 41/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3916 - accuracy: 0.8838 - val_loss: 0.3790 - val_accuracy: 0.8939
# Epoch 42/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3820 - accuracy: 0.8895 - val_loss: 0.3901 - val_accuracy: 0.8939
# Epoch 43/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3820 - accuracy: 0.8819 - val_loss: 0.3935 - val_accuracy: 0.8864
# Epoch 44/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3983 - accuracy: 0.8762 - val_loss: 0.4073 - val_accuracy: 0.8636
# Epoch 45/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3847 - accuracy: 0.8895 - val_loss: 0.3781 - val_accuracy: 0.8939
# Epoch 46/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3759 - accuracy: 0.8895 - val_loss: 0.4004 - val_accuracy: 0.8939
# Epoch 47/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3834 - accuracy: 0.8895 - val_loss: 0.3933 - val_accuracy: 0.8939
# Epoch 48/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3777 - accuracy: 0.8876 - val_loss: 0.3881 - val_accuracy: 0.8864
# Epoch 49/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4061 - accuracy: 0.8800 - val_loss: 0.3949 - val_accuracy: 0.8864
# Epoch 50/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3927 - accuracy: 0.8857 - val_loss: 0.4326 - val_accuracy: 0.8712
# Epoch 51/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3937 - accuracy: 0.8781 - val_loss: 0.3827 - val_accuracy: 0.8939
# Epoch 52/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3816 - accuracy: 0.8857 - val_loss: 0.3917 - val_accuracy: 0.8939
# Epoch 53/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3774 - accuracy: 0.8819 - val_loss: 0.4119 - val_accuracy: 0.8939
# Epoch 54/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3797 - accuracy: 0.8895 - val_loss: 0.4033 - val_accuracy: 0.8939
# Epoch 55/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3779 - accuracy: 0.8819 - val_loss: 0.3880 - val_accuracy: 0.8939
# Epoch 56/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3717 - accuracy: 0.8895 - val_loss: 0.3833 - val_accuracy: 0.8939
# Epoch 57/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3718 - accuracy: 0.8895 - val_loss: 0.3783 - val_accuracy: 0.8939
# Epoch 58/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3727 - accuracy: 0.8857 - val_loss: 0.3816 - val_accuracy: 0.8939
# Epoch 59/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3692 - accuracy: 0.8895 - val_loss: 0.3877 - val_accuracy: 0.8864
# Epoch 60/100
# 5/5 [==============================] - 0s 17ms/step - loss: 0.3681 - accuracy: 0.8895 - val_loss: 0.3698 - val_accuracy: 0.8939
# Epoch 61/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3668 - accuracy: 0.8895 - val_loss: 0.3617 - val_accuracy: 0.8939
# Epoch 62/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3658 - accuracy: 0.8895 - val_loss: 0.3604 - val_accuracy: 0.8939
# Epoch 63/100
# 5/5 [==============================] - 0s 18ms/step - loss: 0.3647 - accuracy: 0.8876 - val_loss: 0.3604 - val_accuracy: 0.8939
# Epoch 64/100
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3619 - accuracy: 0.8895 - val_loss: 0.3631 - val_accuracy: 0.8939
# Epoch 65/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3628 - accuracy: 0.8895 - val_loss: 0.3807 - val_accuracy: 0.8939
# Epoch 66/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3645 - accuracy: 0.8895 - val_loss: 0.3789 - val_accuracy: 0.8939
# Epoch 67/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3643 - accuracy: 0.8876 - val_loss: 0.3704 - val_accuracy: 0.8939
# Epoch 68/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3625 - accuracy: 0.8895 - val_loss: 0.3849 - val_accuracy: 0.8939
# Epoch 69/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3707 - accuracy: 0.8895 - val_loss: 0.3685 - val_accuracy: 0.8939
# Epoch 70/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3736 - accuracy: 0.8933 - val_loss: 0.3656 - val_accuracy: 0.8939
# Epoch 71/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3599 - accuracy: 0.8895 - val_loss: 0.3783 - val_accuracy: 0.8939
# Epoch 72/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3724 - accuracy: 0.8895 - val_loss: 0.3719 - val_accuracy: 0.8939
# Epoch 73/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3698 - accuracy: 0.8876 - val_loss: 0.3706 - val_accuracy: 0.8939
# Epoch 74/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3561 - accuracy: 0.8876 - val_loss: 0.4069 - val_accuracy: 0.8864
# Epoch 75/100
# 5/5 [==============================] - 0s 15ms/step - loss: 0.3819 - accuracy: 0.8895 - val_loss: 0.4002 - val_accuracy: 0.8788
# Epoch 76/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3724 - accuracy: 0.8876 - val_loss: 0.3796 - val_accuracy: 0.8939
# Epoch 77/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3617 - accuracy: 0.8952 - val_loss: 0.3836 - val_accuracy: 0.8939
# Epoch 78/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3639 - accuracy: 0.8895 - val_loss: 0.3760 - val_accuracy: 0.8939
# Epoch 79/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3557 - accuracy: 0.8914 - val_loss: 0.3889 - val_accuracy: 0.8864
# Epoch 80/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3560 - accuracy: 0.8895 - val_loss: 0.3779 - val_accuracy: 0.8864
# Epoch 81/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3555 - accuracy: 0.8895 - val_loss: 0.3703 - val_accuracy: 0.8864
# Epoch 82/100
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3558 - accuracy: 0.8895 - val_loss: 0.3623 - val_accuracy: 0.8939
# Epoch 83/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3629 - accuracy: 0.8914 - val_loss: 0.3570 - val_accuracy: 0.8939
# Epoch 84/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3568 - accuracy: 0.8933 - val_loss: 0.3661 - val_accuracy: 0.8939
# Epoch 85/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3576 - accuracy: 0.8876 - val_loss: 0.3725 - val_accuracy: 0.8864
# Epoch 86/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3482 - accuracy: 0.8895 - val_loss: 0.3618 - val_accuracy: 0.8939
# Epoch 87/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3552 - accuracy: 0.8895 - val_loss: 0.3496 - val_accuracy: 0.8939
# Epoch 88/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3526 - accuracy: 0.8933 - val_loss: 0.3554 - val_accuracy: 0.8939
# Epoch 89/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3516 - accuracy: 0.8876 - val_loss: 0.4075 - val_accuracy: 0.8864
# Epoch 90/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3591 - accuracy: 0.8838 - val_loss: 0.3863 - val_accuracy: 0.8939
# Epoch 91/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3524 - accuracy: 0.8933 - val_loss: 0.3727 - val_accuracy: 0.9015
# Epoch 92/100
# 5/5 [==============================] - 0s 13ms/step - loss: 0.3511 - accuracy: 0.8933 - val_loss: 0.3775 - val_accuracy: 0.8939
# Epoch 93/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3478 - accuracy: 0.8914 - val_loss: 0.4097 - val_accuracy: 0.8864
# Epoch 94/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3605 - accuracy: 0.8857 - val_loss: 0.4008 - val_accuracy: 0.8864
# Epoch 95/100
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3622 - accuracy: 0.8914 - val_loss: 0.3685 - val_accuracy: 0.9015
# Epoch 96/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3545 - accuracy: 0.8933 - val_loss: 0.3583 - val_accuracy: 0.9015
# Epoch 97/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3453 - accuracy: 0.8914 - val_loss: 0.3684 - val_accuracy: 0.8864
# Epoch 98/100
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3490 - accuracy: 0.8857 - val_loss: 0.3780 - val_accuracy: 0.8864
# Epoch 99/100
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3478 - accuracy: 0.8857 - val_loss: 0.3630 - val_accuracy: 0.8864
# Epoch 100/100
# 5/5 [==============================] - 0s 11ms/step - loss: 0.3418 - accuracy: 0.8895 - val_loss: 0.3605 - val_accuracy: 0.8864

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 64)                704
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  dense_11 (Dense)            (None, 64)                4160
#
#  dense_12 (Dense)            (None, 64)                4160
#
#  dense_13 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 13379 (52.26 KB)
# Trainable params: 13379 (52.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
def plot_graphs(history, string):
    plt.plot(history.history[string], color = 'green')
    plt.plot(history.history['val_'+string], color = 'orange')
    plt.xlabel('epoch')
    plt.xlabel(string)
    plt.legend([string, "val_"+string])
    plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %%
evaluation = model.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3605 - accuracy: 0.8864

# %%
ann_pred = np.argmax(model.predict(X_test),axis=1)
ann_pred
# Out:
# 5/5 [==============================] - 0s 2ms/step
# array([2, 2, 2, 1, 0, 1, 2, 2, 1, 0, 0, 1, 0, 0, 0, 0, 2, 1, 0, 1, 0, 1,
#        0, 2, 2, 2, 1, 1, 1, 2, 2, 1, 1, 1, 1, 2, 1, 1, 1, 2, 2, 1, 1, 0,
#        1, 0, 2, 2, 0, 2, 2, 0, 1, 0, 0, 2, 0, 2, 1, 2, 0, 1, 1, 2, 2, 2,
#        1, 1, 2, 0, 0, 1, 0, 1, 1, 0, 2, 2, 2, 1, 1, 2, 1, 2, 2, 1, 0, 1,
#        0, 1, 2, 1, 2, 2, 1, 1, 2, 1, 1, 2, 2, 2, 2, 1, 1, 1, 1, 1, 2, 1,
#        2, 2, 2, 2, 1, 2, 1, 1, 0, 1, 1, 0, 0, 2, 0, 1, 2, 1, 0, 1, 2, 2],
#       dtype=int64)

# %%
print ('accuracy_score: ',accuracy_score(ann_pred, y_test))
print ('f1_score: ',f1_score(ann_pred, y_test, pos_label='positive', average='micro'))
print ('recall_score: ',recall_score(ann_pred, y_test, pos_label='positive', average='micro'))
print ('precision_score: ',precision_score(ann_pred, y_test, pos_label='positive', average='micro'))
# Out:
# accuracy_score:  0.8863636363636364
# f1_score:  0.8863636363636365
# recall_score:  0.8863636363636364
# precision_score:  0.8863636363636364

# %%
print(classification_report(y_test, ann_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83        29
#            1       0.87      0.90      0.89        52
#            2       0.94      0.90      0.92        51
#
#     accuracy                           0.89       132
#    macro avg       0.88      0.88      0.88       132
# weighted avg       0.89      0.89      0.89       132

# %%
# Create the confusion matrix
confusion = confusion_matrix(ann_pred, y_test)

# Create a heatmap of the confusion matrix
sns.heatmap(confusion, annot=True, cmap="Blues", fmt="d")

# Set the axis labels
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")

# Set the title
plt.title("Confusion Matrix")

# Display the plot
plt.show()

# %% [markdown]
# # Save Model

# %%
# Save your model
try:
    model.save('saved_model_ann')
    model.save('model_ann.h5')
    print('Model saved successfully!')

    # Load the saved model to check for errors
    loaded_model = tf.keras.models.load_model('saved_model_ann')
    print('Model loaded successfully after saving.')

except Exception as e:
    # Handle exceptions during saving or loading
    print(f'Error during saving or loading: {e}')
# Out:
# INFO:tensorflow:Assets written to: saved_model_ann\assets
# INFO:tensorflow:Assets written to: saved_model_ann\assets
# Model saved successfully!
# Model loaded successfully after saving.

# %% [markdown]
# # Last Testing

# %%
# Testing feature to check for errors before exporting the model
try:
    # Perform testing operations here
    test_predictions = model.predict(X_test)
    test_predictions = np.argmax(test_predictions, axis=1)

    # Additional testing metrics (if needed)
    test_accuracy = accuracy_score(y_test, test_predictions)
    test_f1 = f1_score(y_test, test_predictions, pos_label='positive', average='micro')

    # Print or log the testing results
    print('Testing Results:')
    print(f'Test Accuracy: {test_accuracy}')
    print(f'Test F1 Score: {test_f1}')

except Exception as e:
    # Handle exceptions during testing
    print(f'Error during testing: {e}')
# Out:
# 5/5 [==============================] - 0s 3ms/step
# Testing Results:
# Test Accuracy: 0.8863636363636364
# Test F1 Score: 0.8863636363636365

# %%
# Create a smaller validation set from the test set
X_val, X_test_final, y_val, y_test_final = train_test_split(X_test, y_test, test_size=0.5, random_state=42)

# Use the validation set for final check
val_predictions = model.predict(X_val)
val_predictions = np.argmax(val_predictions, axis=1)

# Compare predictions to actual values
correct_val = np.sum(val_predictions == y_val)
total_val = len(y_val)
print(f'Total correct predictions out of {total_val} validation points : {correct_val}')
print(f'Accuracy of model on validation data: {correct_val/total_val}')
# Out:
# 3/3 [==============================] - 0s 3ms/step
# Total correct predictions out of 66 validation points : 61
# Accuracy of model on validation data: 0.9242424242424242

# %% [markdown]
# # Export Model

# %%
# If the validation accuracy is acceptable, proceed with saving and conversion
if correct_val/total_val > 0.85:  # assuming 85% is the acceptable accuracy
    # Convert the SavedModel to TFLite format with optimizations
    converter = tf.lite.TFLiteConverter.from_saved_model('saved_model_ann')
    converter.optimizations = [tf.lite.Optimize.DEFAULT]  # Apply default optimizations
    tflite_model = converter.convert()

    # Save the TFLite model to a file
    with open('model_ann.tflite', 'wb') as f:
        f.write(tflite_model)
else:
    print("The model did not reach the acceptable accuracy on the validation set. Please consider retraining or tuning the model.")

# %% [markdown]
# # Mencoba model

# %%
# Menggunakan MinMaxScaler yang sama yang digunakan selama pelatihan model
scaler = MinMaxScaler()

# Contoh data input untuk prediksi
input_data = pd.DataFrame({
    'Gender': [0],
    'Age': [53],
    'Sleep_Duration': [8.3],
    'Sleep_Quality': [5],
    'Physical_Activity_Level': [30],
    'Stress_Level': [0],
    'BMI_Category': [0],
    'Heart_Rate': [65],
    'Daily_Steps': [5000],
    'BP_Category': [0]
})

# Lakukan normalisasi pada variabel yang perlu dinormalisasi
input_data[['Age', 'Sleep_Duration', 'Physical_Activity_Level', 'Heart_Rate', 'Daily_Steps']] = scaler.fit_transform(input_data[['Age', 'Sleep_Duration', 'Physical_Activity_Level', 'Heart_Rate', 'Daily_Steps']])

# Load model yang telah disimpan sebelumnya
loaded_model = tf.keras.models.load_model('model_ann.h5')

# Lakukan prediksi
prediction = loaded_model.predict(input_data)

# Ambil kelas prediksi (misalnya, menggunakan argmax)
predicted_class = np.argmax(prediction, axis=1)

print("Predicted Sleep Disorder Class:", predicted_class)
# Out:
# 1/1 [==============================] - 0s 110ms/step
# Predicted Sleep Disorder Class: [1]
